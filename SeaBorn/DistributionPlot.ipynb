# %%
import seaborn as sns

# %%
# %matplotlib inline
sns.set_style('darkgrid')

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])
#Kernel Density Estimation or a KDE in te histogram
# Out:
# /var/folders/l5/r131f0_163sc57m30fj7cm4m0000gn/T/ipykernel_89782/3456287622.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde=False,bins=40)
# Out:
# /var/folders/l5/r131f0_163sc57m30fj7cm4m0000gn/T/ipykernel_89782/168061831.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],kde=False,bins=40)
# <Axes: xlabel='total_bill'>

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.pairplot(tips,hue='sex',palette='cool') 
#pairplot take a long time if your data frame is large
#hue argument passes in a column name of a categorical column such as the sex column

# %%
sns.rugplot(tips['total_bill'])

#a rugplot is a siple concept drawing a draw a dash mor for every univariant distribution one single variable
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.displot(tips['total_bill'],kde=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

dataset = np.random.randn(25)

sns.rugplot(dataset);

x_min = dataset.min() - 2
x_max = dataset.max() + 2

x_axis = np.linspace(x_min,x_max,100)
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practictal_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2

kernel_list = []
for data_point in dataset:
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)

    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey', alpha=0.5)
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
sum_of_kde = np.sum(kernel_list,axis=0)
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

sns.rugplot(dataset,c= 'indianred')
plt.yticks()

plt.suptitle('Sum of the Basis Function')
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Function')

# %%
#distribution plot types 
#distplot see a displot and see the kde 
#if you want the kde use sns.kdeplot(tips['total_bill])
#jointplot takes two columns
#pairplot builing in the joint plot bassing in a pa
#rugplot help build the logic of the kernel density estimation plot
