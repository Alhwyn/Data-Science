# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('9810000101-eng.csv')

# %%
df.head()
# Out:
#   Population and dwelling counts (11) Population, 2021 Population, 2016  \
# 0                            Canada 2       36,991,981       35,151,728
# 1           Newfoundland and Labrador          510,550          519,716
# 2                Prince Edward Island          154,331          142,907
# 3                         Nova Scotia          969,383          923,598
# 4                       New Brunswick          775,610          747,101
#
#    Population percentage change, 2016 to 2021 Total private dwellings, 2021  \
# 0                                         5.2                    16,284,235
# 1                                        -1.8                       269,184
# 2                                         8.0                        74,934
# 3                                         5.0                       476,007
# 4                                         3.8                       366,146
#
#   Total private dwellings, 2016  \
# 0                    15,412,443
# ...

# %%
df
# Out:
#    Population and dwelling counts (11) Population, 2021 Population, 2016  \
# 0                             Canada 2       36,991,981       35,151,728
# 1            Newfoundland and Labrador          510,550          519,716
# 2                 Prince Edward Island          154,331          142,907
# 3                          Nova Scotia          969,383          923,598
# 4                        New Brunswick          775,610          747,101
# 5                             Quebec 2        8,501,833        8,164,361
# 6                            Ontario 2       14,223,942       13,448,494
# 7                           Manitoba 2        1,342,153        1,278,365
# 8                       Saskatchewan 2        1,132,505        1,098,352
# 9                            Alberta 2        4,262,635        4,067,175
# 10                  British Columbia 2        5,000,879        4,648,055
# 11                               Yukon           40,232           35,874
# ...

# %%
#E
df[['Population and dwelling counts (11)', 'Population, 2021', 'Population, 2016']]
# Out:
#    Population and dwelling counts (11) Population, 2021 Population, 2016
# 0                             Canada 2       36,991,981       35,151,728
# 1            Newfoundland and Labrador          510,550          519,716
# 2                 Prince Edward Island          154,331          142,907
# 3                          Nova Scotia          969,383          923,598
# 4                        New Brunswick          775,610          747,101
# 5                             Quebec 2        8,501,833        8,164,361
# 6                            Ontario 2       14,223,942       13,448,494
# 7                           Manitoba 2        1,342,153        1,278,365
# 8                       Saskatchewan 2        1,132,505        1,098,352
# 9                            Alberta 2        4,262,635        4,067,175
# 10                  British Columbia 2        5,000,879        4,648,055
# 11                               Yukon           40,232           35,874
# ...

# %%
df['Population, 2016'] = df['Population, 2016'].str.replace(',', '').astype(int)

# %%
df[df['Population, 2016']<1000000]
# Out:
#    Population and dwelling counts (11)  Population, 2021  Population, 2016  \
# 1            Newfoundland and Labrador            510550            519716
# 2                 Prince Edward Island            154331            142907
# 3                          Nova Scotia            969383            923598
# 4                        New Brunswick            775610            747101
# 11                               Yukon             40232             35874
# 12               Northwest Territories             41070             41786
# 13                             Nunavut             36858             35944
#
#     Population percentage change, 2016 to 2021 Total private dwellings, 2021  \
# 1                                         -1.8                       269,184
# 2                                          8.0                        74,934
# 3                                          5.0                       476,007
# ...

# %%
df[df['Population, 2016']>5000000]
# Out:
#   Population and dwelling counts (11)  Population, 2021  Population, 2016  \
# 0                            Canada 2          36991981          35151728
# 5                            Quebec 2           8501833           8164361
# 6                           Ontario 2          14223942          13448494
#
#    Population percentage change, 2016 to 2021 Total private dwellings, 2021  \
# 0                                         5.2                    16,284,235
# 5                                         4.1                     4,050,164
# 6                                         5.8                     5,929,250
#
#   Total private dwellings, 2016  \
# 0                    15,412,443
# 5                     3,858,943
# 6                     5,598,391
#
#    Total private dwellings percentage change, 2016 to 2021  \
# 0                                                5.7
# 5                                                5.0
# 6                                                5.9
#
# ...
